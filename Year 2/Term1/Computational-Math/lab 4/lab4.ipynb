# %%
'''
Computational Mathematics
Lab №4
# 1

Author: Eugene Lavrinovych
'''


import matplotlib.pyplot as plt
import numpy as np
from scipy.misc import derivative


def to_show(arr):
    for i in range(len(arr)):
        arr[i] = round(arr[i], 2)
    arr = '\n'.join(map(str, arr))
    return arr


def f(x):
    return x**5 - 4*x**3 + (1.5*x) / (1+x**2)


def bisection(a, b, e=1e-8):
    if np.sign(f(a)) == np.sign(f(b)):
        raise ValueError('f(a) and f(b) must have different signs')
    lst_e = []
    f_a = f(a)
    for i in range(1, 1000):
        lst_e.append(abs(b-a))
        x = a + (b - a)/2
        f_x = f(x)
        print(f'i: {i}    a: {a:.8f}    b: {b:.8f}    |b-a|: {abs(b-a):.8f}    f(x): {f_x:.8f}')
        if np.sign(f_a) == np.sign(f_x):
            a = x
        else:
            b = x
        if abs(b-a) > e:
            continue
        else:
            x = a + (b-a)/2
            print(f'x: {x:.8f}')
            return x, lst_e
        

def chord(a, b, e=1e-8):
    if np.sign(f(a)) == np.sign(f(b)):
        raise ValueError('f(a) and f(b) must have different signs')
    lst_e = []
    f_a = f(a)
    f_b = f(b)
    x = a
    for i in range(1, 1000):
        lst_e.append(abs(b - a))
        x_prev = x
        x = a - f(a)*((b-a) / (f(b) - f(a)))
        f_x = f(x)
        print(f'i: {i}    a: {a:.8f}    b: {b:.8f}    |b-a|: {abs(b - a):.8f}    f(x): {f_x:.8f}'
              f'    |x_prev - x|: {abs(x_prev - x):.8f}')
        if np.sign(f_a) == np.sign(f_x):
            a = x
            f_a = f_x
        else:
            b = x
            f_b = f_x
        if not abs(x_prev-x) < e:
            continue
        else:
            print(f'x: {x:.8f}')
            return x, lst_e

# %%
# Lab 3

x = np.arange(-3, 3.1, 0.4)
y = [f(i) for i in x]
F1 = [derivative(f, i) for i in x]
F2 = [derivative(f, i, n=2) for i in x]

plt.title('f(x) = x**5 - 4*x**3 + (1.5*x) / (1+x**2)')
plt.plot(x, y)
plt.axis([-3, 3, -8, 10])

plt.text(4, -5, f'x\n{to_show(x)}')
plt.text(5, -5, f'F\n{to_show(y)}')
plt.text(6, -5, f'F`\n{to_show(F1)}')
plt.text(7, -5, f'F``\n{to_show(F2)}')

plt.show()

# %%
# Lab 4
a = 1
b = 3
e = 1e-4

# %%
# Bisection method 
bis = bisection(a, b, e)
# Out:
# i: 1    a: 1.00000000    b: 3.00000000    |b-a|: 2.00000000    f(x): 0.60000000
# i: 2    a: 1.00000000    b: 2.00000000    |b-a|: 1.00000000    f(x): -5.21394231
# i: 3    a: 1.50000000    b: 2.00000000    |b-a|: 0.50000000    f(x): -4.37826022
# i: 4    a: 1.75000000    b: 2.00000000    |b-a|: 0.25000000    f(x): -2.57006424
# i: 5    a: 1.87500000    b: 2.00000000    |b-a|: 0.12500000    f(x): -1.17854807
# i: 6    a: 1.93750000    b: 2.00000000    |b-a|: 0.06250000    f(x): -0.34075372
# i: 7    a: 1.96875000    b: 2.00000000    |b-a|: 0.03125000    f(x): 0.11635344
# i: 8    a: 1.96875000    b: 1.98437500    |b-a|: 0.01562500    f(x): -0.11546704
# i: 9    a: 1.97656250    b: 1.98437500    |b-a|: 0.00781250    f(x): -0.00037981
# i: 10    a: 1.98046875    b: 1.98437500    |b-a|: 0.00390625    f(x): 0.05778027
# i: 11    a: 1.98046875    b: 1.98242188    |b-a|: 0.00195312    f(x): 0.02864869
# i: 12    a: 1.98046875    b: 1.98144531    |b-a|: 0.00097656    f(x): 0.01412157
# i: 13    a: 1.98046875    b: 1.98095703    |b-a|: 0.00048828    f(x): 0.00686766
# i: 14    a: 1.98046875    b: 1.98071289    |b-a|: 0.00024414    f(x): 0.00324312
# i: 15    a: 1.98046875    b: 1.98059082    |b-a|: 0.00012207    f(x): 0.00143145
# x: 1.98049927

# %%
# Chord method
_chord = chord(a, b, e)
# Out:
# i: 1    a: 1.00000000    b: 3.00000000    |b-a|: 2.00000000    f(x): -2.48106657    |x_prev - x|: 0.03267974
# i: 2    a: 1.03267974    b: 3.00000000    |b-a|: 1.96732026    f(x): -2.73536005    |x_prev - x|: 0.03538762
# i: 3    a: 1.06806736    b: 3.00000000    |b-a|: 1.93193264    f(x): -3.01272169    |x_prev - x|: 0.03824234
# i: 4    a: 1.10630970    b: 3.00000000    |b-a|: 1.89369030    f(x): -3.31146084    |x_prev - x|: 0.04120359
# i: 5    a: 1.14751329    b: 3.00000000    |b-a|: 1.85248671    f(x): -3.62766037    |x_prev - x|: 0.04420851
# i: 6    a: 1.19172180    b: 3.00000000    |b-a|: 1.80827820    f(x): -3.95438065    |x_prev - x|: 0.04716659
# i: 7    a: 1.23888839    b: 3.00000000    |b-a|: 1.76111161    f(x): -4.28088184    |x_prev - x|: 0.04995615
# i: 8    a: 1.28884454    b: 3.00000000    |b-a|: 1.71115546    f(x): -4.59209328    |x_prev - x|: 0.05242402
# i: 9    a: 1.34126856    b: 3.00000000    |b-a|: 1.65873144    f(x): -4.86867426    |x_prev - x|: 0.05439114
# i: 10    a: 1.39565970    b: 3.00000000    |b-a|: 1.60434030    f(x): -5.08807005    |x_prev - x|: 0.05566622
# i: 11    a: 1.45132592    b: 3.00000000    |b-a|: 1.54867408    f(x): -5.22686703    |x_prev - x|: 0.05606852
# i: 12    a: 1.50739445    b: 3.00000000    |b-a|: 1.49260555    f(x): -5.26440286    |x_prev - x|: 0.05545795
# i: 13    a: 1.56285240    b: 3.00000000    |b-a|: 1.43714760    f(x): -5.18701212    |x_prev - x|: 0.05376652
# i: 14    a: 1.61661892    b: 3.00000000    |b-a|: 1.38338108    f(x): -4.99171557    |x_prev - x|: 0.05102223
# i: 15    a: 1.66764115    b: 3.00000000    |b-a|: 1.33235885    f(x): -4.68798015    |x_prev - x|: 0.04735599
# i: 16    a: 1.71499714    b: 3.00000000    |b-a|: 1.28500286    f(x): -4.29667326    |x_prev - x|: 0.04298669
# i: 17    a: 1.75798383    b: 3.00000000    |b-a|: 1.24201617    f(x): -3.84637931    |x_prev - x|: 0.03818723
# i: 18    a: 1.79617106    b: 3.00000000    |b-a|: 1.20382894    f(x): -3.36827884    |x_prev - x|: 0.03324123
# i: 19    a: 1.82941228    b: 3.00000000    |b-a|: 1.17058772    f(x): -2.89121613    |x_prev - x|: 0.02840307
# i: 20    a: 1.85781536    b: 3.00000000    |b-a|: 1.14218464    f(x): -2.43823282    |x_prev - x|: 0.02387071
# i: 21    a: 1.88168607    b: 3.00000000    |b-a|: 1.11831393    f(x): -2.02505435    |x_prev - x|: 0.01977478
# i: 22    a: 1.90146085    b: 3.00000000    |b-a|: 1.09853915    f(x): -1.66027768    |x_prev - x|: 0.01618186
# i: 23    a: 1.91764270    b: 3.00000000    |b-a|: 1.08235730    f(x): -1.34662492    |x_prev - x|: 0.01310634
# i: 24    a: 1.93074904    b: 3.00000000    |b-a|: 1.06925096    f(x): -1.08260649    |x_prev - x|: 0.01052570
# i: 25    a: 1.94127474    b: 3.00000000    |b-a|: 1.05872526    f(x): -0.86412232    |x_prev - x|: 0.00839494
# i: 26    a: 1.94966968    b: 3.00000000    |b-a|: 1.05033032    f(x): -0.68575730    |x_prev - x|: 0.00665825
# i: 27    a: 1.95632793    b: 3.00000000    |b-a|: 1.04367207    f(x): -0.54170388    |x_prev - x|: 0.00525729
# i: 28    a: 1.96158523    b: 3.00000000    |b-a|: 1.03841477    f(x): -0.42634679    |x_prev - x|: 0.00413638
# i: 29    a: 1.96572161    b: 3.00000000    |b-a|: 1.03427839    f(x): -0.33458582    |x_prev - x|: 0.00324531
# i: 30    a: 1.96896692    b: 3.00000000    |b-a|: 1.03103308    f(x): -0.26197694    |x_prev - x|: 0.00254056
# i: 31    a: 1.97150748    b: 3.00000000    |b-a|: 1.02849252    f(x): -0.20475873    |x_prev - x|: 0.00198539
# i: 32    a: 1.97349287    b: 3.00000000    |b-a|: 1.02650713    f(x): -0.15981372    |x_prev - x|: 0.00154942
# i: 33    a: 1.97504229    b: 3.00000000    |b-a|: 1.02495771    f(x): -0.12459789    |x_prev - x|: 0.00120789
# i: 34    a: 1.97625019    b: 3.00000000    |b-a|: 1.02374981    f(x): -0.09705917    |x_prev - x|: 0.00094086
# i: 35    a: 1.97719105    b: 3.00000000    |b-a|: 1.02280895    f(x): -0.07555677    |x_prev - x|: 0.00073239
# i: 36    a: 1.97792344    b: 3.00000000    |b-a|: 1.02207656    f(x): -0.05878751    |x_prev - x|: 0.00056982
# i: 37    a: 1.97849325    b: 3.00000000    |b-a|: 1.02150675    f(x): -0.04572160    |x_prev - x|: 0.00044316
# i: 38    a: 1.97893641    b: 3.00000000    |b-a|: 1.02106359    f(x): -0.03554852    |x_prev - x|: 0.00034455
# i: 39    a: 1.97928096    b: 3.00000000    |b-a|: 1.02071904    f(x): -0.02763220    |x_prev - x|: 0.00026781
# i: 40    a: 1.97954877    b: 3.00000000    |b-a|: 1.02045123    f(x): -0.02147469    |x_prev - x|: 0.00020813
# i: 41    a: 1.97975691    b: 3.00000000    |b-a|: 1.02024309    f(x): -0.01668685    |x_prev - x|: 0.00016173
# i: 42    a: 1.97991863    b: 3.00000000    |b-a|: 1.02008137    f(x): -0.01296498    |x_prev - x|: 0.00012565
# i: 43    a: 1.98004429    b: 3.00000000    |b-a|: 1.01995571    f(x): -0.01007235    |x_prev - x|: 0.00009762
# x: 1.98014191

# %%
# Lg graph
fig2, (lgbis, lgchord) = plt.subplots(1, 2)
fig2.tight_layout(pad=3.0)
lgbis.plot(bis[1])
lgbis.set_title('Bisection lg')
lgbis.set_yscale('log')

lgchord.plot(_chord[1])
lgchord.set_title('Chord lg')
lgchord.set_yscale('log')

plt.show()

# %%
# Methods compare
print(f'Bisection method x: {bis[0]}\nChord method x: {_chord[0]}')
# Out:
# Bisection method x: 1.980499267578125
# Chord method x: 1.9801419051507438
